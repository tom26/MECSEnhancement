# %% [markdown]
# # Supplementary Calculations for *Enhancement in Specific Absorption Rate by Solvent Microencapsulation* by Moore et al 2018
# This notebook contains the code used to create all plots in the paper *Enhancement in Specific Absorption Rate by Solvent Microencapsulation*, by Moore et al (2018). Code is written in Julia v0.5.1, and should be legible to users of MATLAB, Python, or other popular scientific computing packages. Any errors contained herein are due solely to Thomas Moore.

# %% [markdown]
# ## Figure 2. Surface Renewal Theories.
#
# For absorption accompanied by irreversible first-order reaction, expressions for $J/(k_Lc^*)$ (where $J$ is the gas flux, $c^*$ the physical gas concentration at the surface, and $k_L$ the liquid-side mass transfer coefficient) are derived in Danckwerts' *Gas-Liquid Reactions*, p.105-109. Note that due to the linearity of the differential equations and the surface renewal theories, the extension to reversible reactions simply requires $c^*$ be replaced by $\Delta c = c^*-c_{eq}$, where $c_{eq}$ is the concentration of physically dissolved gas (e.g. whole CO2 molecules) at equilibrium with the current bulk liquid composition.

# %%
using PyPlot
M = logspace(-3,3,10000)                                                         #This is the Ha^2
R1 = sqrt(M)./(tanh(sqrt(M)))                                                    #Whitman Model
R2 = π./(4*sqrt(M)).*((4M/π+1/2).*erf(2*sqrt(M/π)) + 2*sqrt(M)/π.*exp(-4M/π))     #Higbie Model
R3 = sqrt(1+M)                                                                   #Dankwets model        

PyPlot.loglog(M,R1,":k",linewidth=1.0)
PyPlot.loglog(M,R2,"--k",linewidth=1.0)
PyPlot.loglog(M,R3,"-k",linewidth=1.0)
PyPlot.legend(["Whitman", "Higbie", "Danckwerts"], fontsize=15.0)
PyPlot.xlabel(L"$Ha^2$",fontsize=15.0)
PyPlot.ylabel(L"$J/(k_LΔc)$",fontsize=15.0);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x10a7beb90>)

# %% [markdown]
# ## Figure 3. Particle Size and Thiele Modulus
# This is simply a plot of $(\phi \coth \phi - 1)/(\phi^2/3)$, which quantifies the influence of particle size on the absorption rate.

# %%
ϕFigure3=linspace(0.00001,10,1000)
PyPlot.plot(ϕFigure3,(ϕFigure3.*coth(ϕFigure3)-1)./(ϕFigure3.^2/3),"k")
PyPlot.xlim([0,10])
PyPlot.ylim([0.2,1])
PyPlot.xlabel(L"ϕ",fontsize=15)
PyPlot.ylabel(L"\frac{\phi \coth\phi - 1}{\phi^2/3}",fontsize=18);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x323494f50>)

# %% [markdown]
# ## Figures 4-7. Mass Transfer Correlations
#
# We first create functions for each of the mass transfer correlations. We then use these functions to create several plots.

# %% [markdown]
# ### Onda et al 1968
# $$
# k_L=0.0051(a_td_p)^{0.4}\left(\frac{\mu g}{\rho}\right)^{1/3}\left(\frac{L}{a_w\mu}\right)^{2/3} \left(\frac{\mu}{\rho \mathcal{D}}\right)^{-1/2}
# $$
#
# where $g$ is the gravitational constant, $d_p$ is the nominal packing diameter (so, for instance, it is 1/2 an inch for 1/2-inch Raschig Rings), $\varepsilon$ is the voidage in the (dry) column, $L$ is the liquid flux through the column, $\mathcal{D}$ is the diffusivity of the gas in the liquid, $\rho$ and $\mu$ are the liquid density and viscosity respectively, and $a_w$ and $a_t$ are the wetted and total packing surface area respectively. These are in turn related by
#
# $$
# \frac{a_w}{a_t} = 1 - \exp\left[-1.45\left(\frac{\sigma_c}{\sigma}\right)^{0.75}\left(\frac{L}{a_t \mu}\right)^{0.1}\left(\frac{L^2 a_t}{\rho^2 g}\right)^{-0.05}\left(\frac{L^2}{\rho \sigma a_t}\right)^{0.2} \right]
# $$
#
# where $\sigma_c$ is the critical surface tension of the packing material, and $\sigma$ is the surface tension of the solvent

# %%
function Onda_kL(D,d_p,L,μ,ρ,a_t,σ_c,σ)
    g = 9.81                                                                              #Gravitational Constant, m/s2
    a_w = a_t * (1-exp(-1.45 * (σ_c/σ)^0.75 * (L/(a_t*μ))^0.1 * (L^2*a_t/(ρ^2*g))^-0.05 * (L^2/(ρ*σ*a_t))^0.2))
    k_L = 0.0051 * (a_t*d_p)^0.4 * (μ*g/ρ)^(1/3) * (L/(a_w*μ))^(2/3) * (μ/(ρ*D))^(-1/2)                          
    return [k_L, a_w]
end;

# %% [markdown]
# ### Shulman et al 1955
#
# $$
# \frac{k_L d_s}{\mathcal{D}} =25.1 \left(\frac{d_sL}{\mu}\right)^{0.45}\left(\frac{\mu}{\rho\mathcal{D}}\right)^{0.5}
# $$
#
# where $d_s$ is the diameter of a sphere with the same surface area as the packing, $L$ is the liquid flow rate per unit area of column, $\mathcal{D}$ is the diffusivity of the gas in the liquid, and $\rho$ and $\mu$ are the liquid density and viscosity respectively. The effective surface area was presented graphically by Shulman et al (1955) and was fitted by Treyball (1980) to the following correlation:
#
# $$
# a = d\left[\frac{808G}{\sqrt{\rho_G}}\right]^q L^h
# $$
#
# where $G$ is the gas flux through the column and $\rho_G$ is the gas density (note that this equation is dimensional, and will only be accurate in SI units.) According to Treybal, this correlation can be extrapolated up to about $10 kg/m^2.s$.

# %%
function Shulmann_kL(D,d_s,L,μ,ρ,G,ρ_gas)
    #Values of Constants d, q and h for 1/2-inch Raschig Rings. c.f. Treybal (1980), p.205.
    d = L < 2.0 ? 28.01 : 14.69
    q = L < 2.0 ? 0.2323*L-0.30 : 0.01114*L+0.148
    h = L < 2.0 ? -1.04 : -0.11
    
    #d = 14.69
    #q = 0.01114*L+0.148
    #h = -0.11
    
    k_L = 25.1 * (D/d_s) * (d_s*L/μ)^0.45 * (μ/(ρ*D))^0.5
    a = d * (808*G/(ρ_gas^0.5))^q * L^h
    return [k_L, a]
end;

# %% [markdown]
# ### Billet and Schultes (1993)
#
# $$
# k_L = C_L \left(\frac{\rho g}{\mu}\right)^{1/6}\left(\frac{\mathcal{D}}{d_h}\right)^{1/2}\left(\frac{L}{\rho a_t}\right)^{1/3}
# $$
#
# where $C_L$ is a packing dependent constant and $d_h$ is the hydraulic diameter of the packing, defined by $4\varepsilon/a_t$. They combine this with a correlation for mass transfer area. For liquids whose surface tension doesn't decrease down the column:
#
# $$
# \frac{a}{a_t} = 1.5(a_td_h)^{-0.5}\left(\frac{Ld_h}{\mu}\right)^{-0.2}\left(\frac{L^2d_h}{\sigma\rho}\right)^{0.75}\left(\frac{L^2}{gd_h\rho^2}\right)^{-0.45}
# $$
#
# For liquids whose surface tension decreases, the account for the Marangoni effect by multiplying this result by $1-2.3\times10^{-4}\big|Ma\big|^{0.5})$ where Ma is the Marangoni number, defined as:
#
# $$
# Ma = \frac{d\sigma}{dx}\frac{\Delta x}{\mathcal{D}\mu a}
# $$

# %%
function BandS_kL(D,d_h,L,μ,ρ,a_t,σ,C_L)
    g = 9.81         #m/s2
    k_L = C_L * (ρ*g/μ)^(1/6) * (D/d_h)^(1/2) * (L/(ρ*a_t))^(1/3)
    a = a_t * 1.5 * (a_t*d_h)^(-0.5) * (L*d_h/μ)^-0.2 * (L^2*d_h/(σ*ρ))^0.75 * (L^2/(g*d_h*ρ^2))^-0.45
    return [k_L, a]
end;

# %% [markdown]
# ### Hanley and Chen 2011
#
# Hanley and Chen (2012) developed a number of correlations for Pall rings, metal IMTP and Mellapak and Flexipak arrangements. Their correlation could be compared with Rocha et al. and Tsai et al. for Mellapak, as well as Onda et al. and Billet and Scholes (and maybe Shulman also) for Pall rings. They all follow the same pattern, which will look familiar to followers of Shulman:
#
# $$
# \frac{k_Ld_h}{\mathcal{D}} = A\left(\frac{d_hL}{\mu}\right)^{\alpha}\left(\frac{\mu}{\rho \mathcal{D}}\right)^{\beta}
# $$
#
# here $d_h$ is the hydraulic diameter. The effective area ("liquid participating in mass transfer") is given by:
#
# $$
# \frac{a}{a_t} = C\left(\frac{\rho_V}{\rho}\right)^{\gamma}\left(\frac{\mu_V}{\mu}\right)^{\zeta}Re_L^XFr_L^{\Delta}We_L^ERe_V^{\Phi}\left(\frac{\cos\theta}{\cos\pi/4}\right)^{t}
# $$
#
# where $\theta$ is the corrugation inclination angle in radians measured from the vertical, and the exponents are various packing-dependent constants. They use the following definitions for these dimensionless groups:
#
# $$
# Re_L = \frac{d_hL}{\mu}
# $$
#
# $$
# Fr_L = \frac{L^2}{\rho^2gd_h}
# $$
#
# $$
# We_L = \frac{d_hL^2}{\rho\sigma}
# $$
#
# $$
# Re_V = \frac{d_hG}{\mu_v}
# $$

# %%
function HandC_kL(D,d_h,L,μ,ρ,a_t,σ,G,μ_v,ρ_v,costheta,Constants)
    (A,α,β,C,γ,ζ,X,Δ,E,Φ,t) = Constants
    g = 9.81      #m/s^2
    Re_L = d_h*L/μ
    Sc_L = μ/(ρ*D)
    Fr = L^2/(ρ^2*g*d_h)
    We = d_h*L^2/(ρ*σ)
    Re_V = d_h*G/μ_v
    k_L = A * (D/d_h) * (Re_L)^α * (Sc_L)^β
    a = a_t * C * (ρ_v/ρ)^γ * (μ_v/μ)^ζ * Re_L^X * Fr^Δ * We^E * Re_V^Φ * (costheta/cos(π/4))^t
    return [k_L,a]
end;

# %% [markdown]
# ### Rocha et al 1996
#
# Rocha et al. 1996 developed the following correlation, valid for many types of structured packing:
#
# $$
# k_L = 2\left(\frac{C\mathcal{D}U}{\pi S}\right)^{1/2}
# $$
#
# Here $S$ is the corrugation side length, $C$ is a constant equal to 0.9 for most structured packings, and $U$ is
#
# $$
# U = \frac{L}{\rho \varepsilon h_L \sin \alpha}
# $$
#
# where $h_L$ is the fractional liquid holdup and $\alpha$ is the structured packing corrugation angle from the horizontal. This is combined with the following correlation for effective surface area, valid for sheet-netal structured packings:
#
# $$
# \frac{a}{a_t} = F_{SE}\frac{29.12 (We\cdot Fr)^{0.15}S^{0.359}}{Re^{0.2}\varepsilon^{0.6}(1-0.93\cos \gamma) \sin^{0.3} \alpha} = F_{SE}F_t
# $$
#
# where $F_{SE}$ is a packing dependent constant and $\theta$ is the contact angle and the other parameters are dimensionless numbers defined as follows:
#
# $$
# We = \frac{L^2 S}{\rho \sigma}
# $$
#
# $$
# Fr = \frac{L^2}{\rho^2 Sg}
# $$
#
# $$
# Re = \frac{LS}{ \mu}
# $$
#
# $\sin \alpha$ is the same as $\cos \theta$ in Hanley and Chen's paper, and the surface tension for metal sheet packings is given by (equation 11 of Rocha et al (1996)):
#
# $$
# \cos\gamma =
# \left\{
# 	\begin{array}{ll}
# 		0.90  & \mbox{if } \sigma \leq 0.055 N/m \\
# 		5.211 \times 10^{-16.835\sigma} & \mbox{if } \sigma \geq 0.055 N/m
# 	\end{array}
# \right.
# $$
#
# Note that we still need to define $h_L$, the liquid holdup. This can be defined via $F_t$ in the $a/a_t$ equation above. From Rocha et al.'s first paper in the series (Rocha et al 1993):
#
# $$
# h_L = \left(4\frac{F_t}{S}\right)^{2/3}\left(\frac{3\mu L}{\rho^2 \sin \alpha \varepsilon g_{eff}}\right)^{1/3}
# $$
#
# here $g_{eff}$ is an effective gravity, but when we are far from flooding, this can safely be treated as $g$.

# %%
function Rocha_kL(D,S,L,μ,ρ,σ,sinalpha,a_t,cosgamma,ɛ,F_SE)
    g = 9.81                 #N/kg
    C = 0.9
    We = L^2*S/(ρ*σ)
    Fr = L^2/(ρ^2*S*g)
    Re = L*S/μ
    F_t = 29.12 * (We*Fr)^0.15 * S^0.359 / (Re^0.2*ɛ^0.6*(1-0.93*cosgamma)*sinalpha^0.3)
    a = a_t * F_SE * F_t
    holdupfrac = (4F_t/S)^(2/3) * (3μ*L/(ρ^2*sinalpha*ɛ*g))^(1/3)
    U = L/(ρ*ɛ*holdupfrac*sinalpha)
    k_L = 2(C*D*U/(π*S))^0.5
    return [k_L,a]
end;

# %% [markdown]
# ### Tsai et al (2011)
#
# Tsai et al (2011) gave the following function for the effective surface area for a chemically-reactive solvent:
#
# $$
# \frac{a}{a_t} = 1.34\left(\left(\frac{\rho}{\sigma}\right)g^{1/3}\left(\frac{L}{\rho}\frac{Bh}{4S}\right)^{4/3}\right)^{0.116}
# $$
#
# where $B$, $h$ and $S$ are packing specific parameters.

# %%
function Tsai_a(ρ,σ,L,a_t,B,h,S)
    g = 9.81        #m/s^2
    a = a_t * 1.34 * (ρ/σ * g^(1/3) * (L/ρ * B*h/(4S))^(4/3))^0.116
    return a
end;

# %% [markdown]
# ## Figures 4-7. Properties of Potassium Carbonate Solutions.
# To use these correlations, we need to know several properties of potassium carbonate solutions.
# ### Second order reaction rate constan $k_{OH^-}$
# Carbon dioxide reacts with hydroxide ions in the $K_2CO_3$ solution according to the following reaction:
#
# $$
# CO_2 + OH^- \rightarrow HCO3^-
# $$
#
# The second order rate constant for this reaction, $k_{OH^-}$, is, according to Astarita et al (1983), given by
#
# $$
# k_{OH^-} = 10^{13.635-2895/T+0.08I}
# $$
#
# where $T$ is the temperature in Kelvin, $I$ the ionic strength in $mol/L$, and $k_{OH^-}$ has units of $L/mol.s$

# %%
kOH_func(T,I) = 10.^(13.635 - 2895./T + 0.08I);

# %% [markdown]
# ### Density of Potasium Carbonate solutions

# %% [markdown]
# Novotny and Sohnel (1985) provide functions for the density of salt solutions at various temperatures and concentrations:
#
# $$
# \rho(t,c) = \rho_w(t) + (A + Bt + Ct^2)c + (D + Et + Ft^2)c^{3/2}
# $$
#
# where $t$ is the temperature in Celsius, $c$ is the concentration in mol/L, $\rho_w$ is the density of pure water, and $A,B,\ldots,F$ are constants. For the density of water, the function of Kell (1975) was used:
#
# $$
# \rho (\text{kg}/\text{m}^3) = \frac{999.83952+16.945176t-7.9870401\times10^{-3}t^2-46.170461\times10^{-6}t^3+105.56302\times10^{-9}t^4-280.5423\times10^{-12}t^5}{1+16.897850\times10^{-3}t}
# $$
#
# where $t$ is again in degrees Celsius.

# %%
#Constants for Potassium Carbonate from Novotny and Sohnel (1985).
A_NandS = 1.358e2
B_NandS = -2.628e-1
C_NandS = 1.986e-3
D_NandS = -1.636e1
E_NandS = 8.768e-2
F_NandS = -5.385e-4

ρ_Wfunc(T) = (999.83952 + 16.945176*(T-273.15)-7.9870401e-3*(T-273.15).^2-46.170461e-6*(T-273.15).^3+105.56302e-9*(T-273.15).^4-280.54253e-12*(T-273.15).^5)./(1+16.897850e-3*(T-273.15))    #Density of water, kg/m3
α_func(T) = A_NandS + B_NandS*(T-273.15) + C_NandS*(T-273.15).^2
β_func(T) = -(D_NandS + E_NandS*(T-273.15) + F_NandS*(T-273.15).^2)
ρ_func(T,c) = ρ_Wfunc(T) + α_func(T)*c - β_func(T)*c^(3/2);         #kg/m3

# %% [markdown]
# ### Viscosity of Potassium Carbonate Solutions

# %% [markdown]
# The viscosity of potassium carbonate solutions was calculated using the correlation of Correia and Kestin (1980):
#
# $$
# \mu(t,m) = \mu(t,0)\left(1+\sum_{i=0}^2\sum_{j=0}^2f_{ij}t^im^{j+1}\right)
# $$
#
# Note that $f_{ij}$ is a matrix of constants, $t$ is temperature in degrees Celsius and their concentration unit, $m$, is molality, in mol/kg, see p. 203 of their paper. This calculation required a correlation for the viscosity of pure water as a function of temperature, and this is provided by Kestin, Sokolov and Wakeham (1978):
#
# $$
# \log \left(\frac{\mu(t)}{\mu(20^oC)}\right) = \frac{20-t}{t+96} (1.2378 - 1.303\times 10^{-3}(20-t)+3.06\times 10^{-6}(20-t)^2+2.55\times 10^{-8}(20-t)^3)
# $$
#
# where once again, $t$ is the temperature in Celsius.

# %%
#Constants for calculation of K2CO3 viscosity, from Correia and Kestin (1980)
f_CandK = [0.2124 0.08072 0.01046;
           0.4697e-2 -0.2120e-2 0.6296e-4;
          -0.3065e-4 0.1962e-4 -0.1955e-5]

μ_0(T) = 1002e-6*10.^((20-(T-273.15))/((T-273.15)+96)*(1.2378-1.303e-3*(20-(T-273.15))+3.06e-6*(20-(T-273.15)).^2+2.55e-8*(20-(T-273.15)).^3))     #Viscosity of pure water, from Kestin, Sokolov and Wakeham (Pa.s)
μ_func(T,m) = μ_0(T).*(1+sum([f_CandK[i+1,j+1]*(T-273.15).^i.*m.^(j+1) for i in 0:2 for j in 0:2]));

# %% [markdown]
# ### Diffusivity of Carbon Dioxide in Potassium Carbonate Solutions

# %% [markdown]
# The diffusivity of carbon dioxide in potassium carbonate solutions is calculated from the diffusivity of CO2 in pure water as measured by Versteeg and Van Swaalj (1988):
#
# $$
# D_{CO2} = 2.35\times10^{-6}\exp(-2119/T)
# $$
#
# where $T$ is the temperature in Kelvin. This is modified for potassium carbonate solutions using the Stokes-Einstein relation, which simply states that $\mathcal{D}\propto 1/\mu$

# %%
D_CO2_Water(T) = 2.35e-6*exp(-2119./T)     #m2/s
D_CO2_func(T,m) = D_CO2_Water(T).*μ_func(T,0)./μ_func(T,m);

# %% [markdown]
# ### Convert wt% to molarity and molality.
# We will often define a potassium carbonate solution by it's wt% (e.g. a 30wt% solution), however the above correlations require the molarity and molality of the solution. We thus define the following function, which is able to convert a weight fraction, $w$, to a molality and a molarity at different temperatures.

# %%
#Function to convert a weight fraction concentration at temperature T to mol/L of solution and mol/kg of water water
using Roots
function express_in_molarity_and_molality(w,T)
    MW_K2CO3 = 138.205               #molecular weight of K2CO3, g/mol
    mval = (w*1000/MW_K2CO3)/(1-w)   #molality, mol/kg water
    c_guess = 3.0; 
    functemp(c) = c - w*ρ_func(T,c)/MW_K2CO3
    cval = Roots.fzero(functemp,3.0) #molality, mol/L of solution
    ρval = ρ_func(T,cval)
    return [ρval cval mval]
end;

# %% [markdown]
# ## Figure 4. $k_L, a, k_La$ and $\alpha E$ for 30wt% K2CO3 flowing through 1/2-Inch Raschig Rings.
#
# Functions for the mass transfer correlations and physical properties of potassium carbonate solutions have already been defined above. These will now be used to plot $k_L, a, k_La$ and $\alpha E$ as functions of the liquid flow rate, $L$. The following properties were used for 1/2-inch ceramic Raschig Rings, taken from Shulman et al (1955) and Billet and Schultes (1993) (the similar $\varepsilon$ values suggest that both papers are considering identical or near-identical Raschig Ring geometries):
#
#  - $a_t = 370.7 \text{m}^2/\text{m}^3$
#  - $d_s = 0.01762 \text{m}$
#  - $\varepsilon = 0.63$
#  - $d_p = 0.0127$, (i.e. $1/2$ and inch)
#  - $C_L = 1.367$
#
# Values for the surface tension of the ceramic material are taken from Wilcox et al (2014), while typical values for the gas density ($1 \text{kg}/\text{m}^2$) and gas flow rate ($0.5 \text{kg}/\text{m}^2\text{s}$) were used.
#
# ### Properties of Column

# %%
#Raschig Ring Data
a_t_Fig4 = 370.7              #1/m
d_s_Fig4 = 0.01762            #m
d_p_Fig4 = 0.0127             #m
ɛ_Fig4   = 0.63
d_h_Fig4 = 4ɛ_Fig4/a_t_Fig4   #m
C_L_Fig4 = 1.367 

#Physical Properties of 30wt% K2Co3 solution, calculated using correlations above.
T_Fig4 = 313.15                       #Temperature, K
wt_pct_Fig4 = 30                      #K2CO3 wt%

#Convert wt% to molarity and molality
(ρ_Fig4, c_Fig4, m_Fig4) = express_in_molarity_and_molality(wt_pct_Fig4/100,T_Fig4)

#Calculate other physical values.
μ_Fig4 = μ_func(T_Fig4,m_Fig4)        #Viscosity, Pa.s
D_Fig4 = D_CO2_func(T_Fig4,m_Fig4)    #Diffusivity, m2/s
I_Fig4 = 1/2.0*(2c_Fig4+4c_Fig4)      #Ionic strength, mol/L
kOH_Fig4 = kOH_func(T_Fig4,I_Fig4)    #L/mol.s Second order rate constant
C_OH_Fig4 = 1e-4                      #mol/L OH- concentration, assuming a pH of 10
k_Fig4 = kOH_Fig4*C_OH_Fig4           #First order rate constant, 1/s
σ_c_Fig4 = .061                       #N/m, ceramic, from Wilcox et al 2014
σ_Fig4 = .087                         #N/m, 5M K2CO3 at 25C, from Wilcox et al 2014
ρ_gas_Fig4 = 1.0                      #kg/m3
G_Fig4 = 0.5                          #kg/m2.s;

# %% [markdown]
# ### Figure 4 Plot.

# %%
L_Fig4 = linspace(1,20,100)                          #Range of liquid flow rate values values, kg/m2.s
L_Fig4_Shulman = linspace(1,10,100)                  #Range of liquid flow rate values values for Shulman's data, kg/m2.s
PyPlot.subplots_adjust(wspace=0.6,hspace=0.6)

#Liquid side mass transfer coefficient, k_L, m/s
kL_Shulman_Fig4 = [Shulmann_kL(D_Fig4,d_s_Fig4,L_Fig4_Shulman[i],μ_Fig4,ρ_Fig4,G_Fig4,ρ_gas_Fig4)[1] for i in 1:length(L_Fig4_Shulman)]
kL_Onda_Fig4    = [Onda_kL(D_Fig4,d_p_Fig4,L_Fig4[i],μ_Fig4,ρ_Fig4,a_t_Fig4,σ_c_Fig4,σ_Fig4)[1] for i in 1:length(L_Fig4)]
kL_BandS_Fig4   = [BandS_kL(D_Fig4,d_h_Fig4,L_Fig4[i],μ_Fig4,ρ_Fig4,a_t_Fig4,σ_Fig4,C_L_Fig4)[1] for i in 1:length(L_Fig4)] 

PyPlot.subplot(221)
PyPlot.plot(L_Fig4_Shulman,kL_Shulman_Fig4,"k")
PyPlot.plot(L_Fig4,kL_Onda_Fig4,"--k")
PyPlot.plot(L_Fig4,kL_BandS_Fig4,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("kL (m/s)")
PyPlot.title("kL")

#Useful Surface area, a_w, m2/m3
a_Shulman_Fig4 = [Shulmann_kL(D_Fig4,d_s_Fig4,L_Fig4_Shulman[i],μ_Fig4,ρ_Fig4,G_Fig4,ρ_gas_Fig4)[2] for i in 1:length(L_Fig4_Shulman)]
a_Onda_Fig4    = [Onda_kL(D_Fig4,d_p_Fig4,L_Fig4[i],μ_Fig4,ρ_Fig4,a_t_Fig4,σ_c_Fig4,σ_Fig4)[2] for i in 1:length(L_Fig4)]
a_BandS_Fig4   = [BandS_kL(D_Fig4,d_h_Fig4,L_Fig4[i],μ_Fig4,ρ_Fig4,a_t_Fig4,σ_Fig4,C_L_Fig4)[2] for i in 1:length(L_Fig4)] 

PyPlot.subplot(222)
PyPlot.plot(L_Fig4_Shulman,a_Shulman_Fig4,"k")
PyPlot.plot(L_Fig4,a_Onda_Fig4,"--k")
PyPlot.plot(L_Fig4,a_BandS_Fig4,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("a (1/m)")
PyPlot.title("a")

#kLa values, 1/s
kLa_Shulman_Fig4 = a_Shulman_Fig4 .* kL_Shulman_Fig4
kLa_Onda_Fig4    = a_Onda_Fig4    .* kL_Onda_Fig4
kLa_BandS_Fig4   = a_BandS_Fig4   .* kL_BandS_Fig4

PyPlot.subplot(223)
PyPlot.plot(L_Fig4_Shulman,kLa_Shulman_Fig4,"k")
PyPlot.plot(L_Fig4,kLa_Onda_Fig4,"--k")
PyPlot.plot(L_Fig4,kLa_BandS_Fig4,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("kLa (1/s)")
PyPlot.title("kLa")
PyPlot.legend(["Shulman","Onda","B&S"])

#Enhancement that mixing of liquid provides to gas flux, αE
αE_Shulman_Fig4 = [sqrt(1+kL_Shulman_Fig4[i]^2/(D_Fig4*k_Fig4)) for i in 1:length(L_Fig4_Shulman)]
αE_Onda_Fig4    = [sqrt(1+kL_Onda_Fig4[i]^2  /(D_Fig4*k_Fig4)) for i in 1:length(L_Fig4)]
αE_BandS_Fig4   = [sqrt(1+kL_BandS_Fig4[i]^2  /(D_Fig4*k_Fig4)) for i in 1:length(L_Fig4)]

PyPlot.subplot(224)
PyPlot.plot(L_Fig4_Shulman,αE_Shulman_Fig4,"k")
PyPlot.plot(L_Fig4,αE_Onda_Fig4,"--k")
PyPlot.plot(L_Fig4,αE_BandS_Fig4,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("αE (1/s)")
PyPlot.title("αE")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3239a8890>)
# PyObject <matplotlib.text.Text object at 0x323d9ef90>

# %% [markdown]
# ## Figure 5. $k_L, a, k_La$ and $\alpha E$ for 30wt% K2CO3 flowing through Mellapak 500Y.
#
# The correlations of Hanley and Chen, Rocha, and Tsai will now be used to plot $k_L, a, k_La$ and $\alpha E$ as functions of the liquid flow rate, $L$. Functions for the mass transfer correlations and physical properties of potassium carbonate solutions flowing over structured packing have already been defined above. The following properties will be used for Mellapak 500Y:
#
#  - $a_t = 500 \text{m}^2/\text{m}^3$  (Rocha et al, 1996)
#  - $F_{SE} = 0.350$         (Rocha et al, 1996)
#  - $\varepsilon = 0.91$   (Rocha et al, 1996)
#  - $\sin\theta = \cos\alpha = 0.707$ (Tsai et al, 2011)
#
# For Tsai et al's correlation (from Tsai et al (2011)):
#  - $B = 9.6\times10^{-3}m$
#  - $h = 6.53\times10^{-3}m$
#  - $S = 8.1\times10^{-3}m$
#
# For Hanley and Chen's correlation (Hanley and Chen, 2011):
#  - $A = 0.33$
#  - $α = 1.0$
#  - $β = 1/3$
#  - $C = 0.539$
#  - $γ = -0.033$
#  - $ζ = 0.090$
#  - $X = -0.153$
#  - $Δ = -0.2$
#  - $E = 0.2$
#  - $Φ = 0.145$
#  - $t = 4.078$
#
# As mentioned above, the contact angle for metal sheet packings is given by (Rocha et al 1996):
#
# $$
# \cos\gamma =
# \left\{
# 	\begin{array}{ll}
# 		0.90  & \mbox{if } \sigma \leq 0.055 N/m \\
# 		5.211 \times 10^{-16.835\sigma} & \mbox{if } \sigma \geq 0.055 N/m
# 	\end{array}
# \right.
# $$
#
#
# Typical values for the gas density ($1 \text{kg}/\text{m}^2$), gas viscosity ($1.8\times10^{-5} Pa.s$) and gas flow rate ($0.5 \text{kg}/\text{m}^2\text{s}$) were used. The functions defined above were used to calculate physical properties of the K2CO3 solution.
#
# ### Properties of Column

# %%
#Properties for Mellapak 250Y
a_t_Fig5 = 500                #m2/m3
ɛ_Fig5 = 0.91 
d_h_Fig5 = 4*ɛ_Fig5/a_t_Fig5
F_SE_Fig5 = 0.350
σ_Fig5 = .087                 #N/m, 5M K2CO3 at 25C, from Wilcox et al 2014
costheta_Fig5 = 0.707         #cos(45 degrees)
sinalpha_Fig5 = costheta_Fig5 
cosgamma_Fig5 = σ_Fig5 < 0.055 ? 0.9 : 5.211*10^(-16.385σ_Fig5)

#Tsai et al Constants
B_Fig5 = 9.6e-3               #m
h_Fig5 = 6.53e-3              #m
S_Fig5 = 8.1e-3               #m

#Hanley and Chen Constants
A_Fig5 = 0.33; α_Fig5 = 1.0; β_Fig5 = 1/3; C_Fig5 = 0.539; 
γ_Fig5 = -0.033; ζ_Fig5 = 0.090; X_Fig5 = -0.153; Δ_Fig5 = -0.2; 
E_Fig5 = 0.2; Φ_Fig5 = 0.145; t_Fig5 = 4.078;
Constants_Fig5 = [A_Fig5,α_Fig5,β_Fig5,C_Fig5,γ_Fig5,ζ_Fig5,X_Fig5,Δ_Fig5,E_Fig5,Φ_Fig5,t_Fig5]

#Physical Properties of 30wt% K2Co3 solution, calculated using correlations above.
T_Fig5 = 313.15                       #Temperature, K
wt_pct_Fig5 = 30                      #K2CO3 wt%

#Convert wt% to molarity and molality
(ρ_Fig5, c_Fig5, m_Fig5) = express_in_molarity_and_molality(wt_pct_Fig5/100,T_Fig5)

#Calculate other physical values.
μ_Fig5 = μ_func(T_Fig5,m_Fig5)        #Viscosity, Pa.s
D_Fig5 = D_CO2_func(T_Fig5,m_Fig5)    #Diffusivity, m2/s
I_Fig5 = 1/2.0*(2c_Fig5+4c_Fig5)      #Ionic strength, mol/L
kOH_Fig5 = kOH_func(T_Fig5,I_Fig5)    #L/mol.s Second order rate constant
C_OH_Fig5 = 1e-4                      #mol/L OH- concentration, assuming a pH of 10
k_Fig5 = kOH_Fig5*C_OH_Fig5           #First order rate constant, 1/s
σ_c_Fig5 = .061                       #N/m, ceramic, from Wilcox et al 2014
σ_Fig5 = .087                         #N/m, 5M K2CO3 at 25C, from Wilcox et al 2014
ρ_v_Fig5 = 1.2                        #kg/m3
μ_v_Fig5 = 1.8e-5                     #Pa.s air
G_Fig5 = 0.5                          #kg/m2.s;

# %% [markdown]
# ### Figure 5 Plot.

# %%
L_Fig5 = linspace(1,20,100)                          #Range of liquid flow rate values values, kg/m2.s
PyPlot.subplots_adjust(wspace=0.6,hspace=0.6)

#Useful Surface area, a_w, m2/m3
a_Rocha_Fig5  = [Rocha_kL(D_Fig5,S_Fig5,L_Fig5[i],μ_Fig5,ρ_Fig5,σ_Fig5,sinalpha_Fig5,a_t_Fig5,cosgamma_Fig5,ɛ_Fig5,F_SE_Fig5)[2] for i in 1:length(L_Fig5)]
a_HandC_Fig5  = [HandC_kL(D_Fig5,d_h_Fig5,L_Fig5[i],μ_Fig5,ρ_Fig5,a_t_Fig5,σ_Fig5,G_Fig5,μ_v_Fig5,ρ_v_Fig5,costheta_Fig5,Constants_Fig5)[2] for i in 1:length(L_Fig5)]
a_Tsai_Fig5   = [Tsai_a(ρ_Fig5,σ_Fig5,L_Fig5[i],a_t_Fig5,B_Fig5,h_Fig5,S_Fig5)[1] for i in 1:length(L_Fig5)] 

PyPlot.subplot(222)
PyPlot.plot(L_Fig5,a_Rocha_Fig5,"k")
PyPlot.plot(L_Fig5,a_HandC_Fig5,"--k")
PyPlot.plot(L_Fig5,a_Tsai_Fig5,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("a (1/m)")
PyPlot.title("a")

#Liquid side mass transfer coefficient, k_L, m/s
kL_Rocha_Fig5  = [Rocha_kL(D_Fig5,S_Fig5,L_Fig5[i],μ_Fig5,ρ_Fig5,σ_Fig5,sinalpha_Fig5,a_t_Fig5,cosgamma_Fig5,ɛ_Fig5,F_SE_Fig5)[1] for i in 1:length(L_Fig5)]
kL_HandC_Fig5  = [HandC_kL(D_Fig5,d_h_Fig5,L_Fig5[i],μ_Fig5,ρ_Fig5,a_t_Fig5,σ_Fig5,G_Fig5,μ_v_Fig5,ρ_v_Fig5,costheta_Fig5,Constants_Fig5)[1] for i in 1:length(L_Fig5)]

#kLa values, 1/s
kLa_Rocha_Fig5 = kL_Rocha_Fig5 .* a_Rocha_Fig5
kLa_HandC_Fig5 = kL_HandC_Fig5 .* a_HandC_Fig5
kLa_mean_Fig5  = 0.5*(kLa_Rocha_Fig5 + kLa_HandC_Fig5)

#kL value for Tsai, using mean kLa value
kL_Tsai_Fig5 = kLa_mean_Fig5 ./ a_Tsai_Fig5

#Plot kL and kLa
PyPlot.subplot(221)
PyPlot.plot(L_Fig5,kL_Rocha_Fig5,"k")
PyPlot.plot(L_Fig5,kL_HandC_Fig5,"--k")
PyPlot.plot(L_Fig5,kL_Tsai_Fig5,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("kL (m/s)")
PyPlot.title("kL")

PyPlot.subplot(223)
PyPlot.plot(L_Fig5,kLa_Rocha_Fig5,"k")
PyPlot.plot(L_Fig5,kLa_HandC_Fig5,"--k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("kLa (1/s)")
PyPlot.title("kLa")

#Enhancement that mixing of liquid provides to gas flux, αE
αE_Rocha_Fig5 = [sqrt(1+kL_Rocha_Fig5[i]^2/(D_Fig5*k_Fig5)) for i in 1:length(L_Fig5)]
αE_HandC_Fig5 = [sqrt(1+kL_HandC_Fig5[i]^2/(D_Fig5*k_Fig5)) for i in 1:length(L_Fig5)]
αE_Tsai_Fig5  = [sqrt(1+kL_Tsai_Fig5[i]^2 /(D_Fig5*k_Fig5)) for i in 1:length(L_Fig5)]

PyPlot.subplot(224)
PyPlot.plot(L_Fig5,αE_Rocha_Fig5,"k")
PyPlot.plot(L_Fig5,αE_HandC_Fig5,"--k")
PyPlot.plot(L_Fig5,αE_Tsai_Fig5,"-.k")
PyPlot.xlabel("L (kg/m2.s)")
PyPlot.ylabel("αE (1/s)")
PyPlot.title("αE")
PyPlot.legend(["Rocha","H&C","Tsai"]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x323e373d0>)

# %% [markdown]
# ## Figure 6. Increase in Area Microencapsulation Provides
# As discussed in the paper, the correlations of Onda et al (1968) and of Tsai et al (2011) are most appropriate for chemical solvents such as K2CO3. Thus with a flow rate of $L=5\text{kg}/\text{m}^2\text{s}$, the useful area in the randomly packed and structured columns are $130 \text{m}^2/\text{m}^3$ and $360\text{m}^2/\text{m}^3$ respectively. On the other hand, the useful area of an absorber containing MECS is $3(1-\varepsilon)/r$, where $r$ is the MECS radius and $1-\varepsilon$ the solid fraction of MECS inside the reactor. Thus, the increase in area MECS can provide is given by:
#
# $$
# \frac{a_{MECS}}{a_{absorber}} = \frac{3(1-\varepsilon)/r}{a_{absorber}}
# $$
#
# We plots this below for various values of $\varepsilon$. We also plot the function $(3/r)/1000$, which has been previously used to quantify the improvement microencapsulation can provide.

# %%
PyPlot.figure()
Rvals = logspace(-4,-3.22,100)/2
PyPlot.loglog(2*Rvals,(3./Rvals)./1000,"k")
PyPlot.loglog(2*Rvals,0.05*3./Rvals./360,":g")
PyPlot.loglog(2*Rvals,0.1*3./Rvals./360,"--g")
PyPlot.loglog(2*Rvals,0.2*3./Rvals./360,"-.g")
PyPlot.loglog(2*Rvals,0.05*3./Rvals./130,":b")
PyPlot.loglog(2*Rvals,0.1*3./Rvals./130,"--b")
PyPlot.loglog(2*Rvals,0.2*3./Rvals./130,"-.b")
PyPlot.legend(["1mm Layer","M500Y, ɛ=0.95","M500Y, ɛ=0.9","M500Y, ɛ=0.8","Raschig, ɛ=0.95","Raschig, ɛ=0.9","Raschig, ɛ=0.8"])
PyPlot.xlabel("MECS Diameter (m)")
PyPlot.ylabel("MECS Area / Area in Packed Column");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x323e23e10>)

# %% [markdown]
# ## Figure 7. $\Gamma$ vs Particle Diameter for Various Packing Types
#
# As described in the paper, the overall improvement in the specific absorption rate that microencapsulation can provide is given by:
#
# $$
# \Gamma \equiv \left(\frac{\alpha(1-\varepsilon)}{\sqrt{1+\text{Ha}^{-2}}}\left(\frac{k}{\mathcal{D}a^2}\right)^{1/2}\right)\left(\frac{\phi\coth\phi-1}{\phi^2/3}\right)
# $$
#
# In this plot, we will calculate this for various MECS (of various radius, in various absorbers with various voidages) and columns (with various packings and a constant liquid flow rate of $L=5\text{kg}/{m}^2\text{s}$.) The amount by which the presence of the shell reduces the gas flux, $\alpha$, is calculated as
#
# $$
# \alpha=\frac{\mathcal{R}_{\text{solvent}}}{\mathcal{R}_{\text{solvent}}+\mathcal{R}_{\text{shell}}}
# $$
#
# where
#
# $$
# \mathcal{R}_{\text{solvent}} = \left[\frac{\mathcal{D}}{r}(\phi \coth \phi - 1)\right]^{-1}
# $$
#
# and
#
# $$
# \mathcal{R}_{\text{shell}} = \frac{Hz}{\mathcal{P}_{\text{shell}}}\frac{r}{r+z}
# $$
#
# where $\mathcal{D}$ is the diffusivity of CO2 in the liquid, $r$ the MECS radius, $H$ the Henry's constant of CO2 in the liquid, $\mathcal{P}_{\text{shell}}$ the permeability of CO2 in the shell, and $z$ the shell thickness. As noted in the paper, we will take:
#
#  - $z = 25 \mu m$
#  - $\mathcal{P}_{\text{shell}} = 3000 \text{barrer} \approx 10^{12} mol/s.Pa.m$
#  - $H = 2.4\times10^{-5} mol/Pa.m^3$, from Knuutila et al (2010)
#
# To simplify the code, we calculate $\Gamma' \equiv \Gamma/(1-\varepsilon)$, and add in various $1-\varepsilon$ values when making the final plot. Note that because $L$ is constant, $k_L$ values are constant in this plot.

# %%
#Properties of Packed Columns, calculated once again via the Tsai and Onda correlations.
L_Fig7 = 5.0                            #Liquid Flowrate, kg/m2.s
kL_Raschig_Fig7  = Onda_kL(D_Fig4,d_p_Fig4,L_Fig7,μ_Fig4,ρ_Fig4,a_t_Fig4,σ_c_Fig4,σ_Fig4)[1]
kL_Melapak_Fig7  = 0.5*(prod(Rocha_kL(D_Fig5,S_Fig5,L_Fig7,μ_Fig5,ρ_Fig5,σ_Fig5,sinalpha_Fig5,a_t_Fig5,cosgamma_Fig5,ɛ_Fig5,F_SE_Fig5)) + prod(HandC_kL(D_Fig5,d_h_Fig5,L_Fig7,μ_Fig5,ρ_Fig5,a_t_Fig5,σ_Fig5,G_Fig5,μ_v_Fig5,ρ_v_Fig5,costheta_Fig5,Constants_Fig5)))/Tsai_a(ρ_Fig5,σ_Fig5,L_Fig7,a_t_Fig5,B_Fig5,h_Fig5,S_Fig5)[1]
a_Raschig_Fig7   = Onda_kL(D_Fig4,d_p_Fig4,L_Fig7,μ_Fig4,ρ_Fig4,a_t_Fig4,σ_c_Fig4,σ_Fig4)[2]
a_Melapak_Fig7   = Tsai_a(ρ_Fig5,σ_Fig5,L_Fig7,a_t_Fig5,B_Fig5,h_Fig5,S_Fig5)[1]

#Properties of MECS
z_Fig7 = 25e-6                          #m
P_Fig7 = 1e-12                          #mol/m.s.Pa
H_Fig7 = 2.4e-5                         #mol/Pa.m3  

#Caluate Γdash values for MECS of various sizes.
r_Fig7 = logspace(0,4,1000)*1e-6        #Range of radii in plot, m
Γdash_Melapak_Fig7  = zeros(1000)
Γdash_Raschig_Fig7  = zeros(1000)

for i in 1:length(r_Fig7)
    ϕ_Fig7 = sqrt(k_Fig5/D_Fig5)*r_Fig7[i]                                      #Thiele Modulus
    Rsolvent_Fig7 = (D_Fig5/r_Fig7[i]*(ϕ_Fig7*coth(ϕ_Fig7)-1))^(-1)             #Solvent-side mass transfer resistance in MECS
    Rshell_Fig7   = H_Fig7*z_Fig7/(P_Fig7)*r_Fig7[i]/(r_Fig7[i]+z_Fig7)          #Shell-side mass transfer resistance in MECS
    α_Fig7 = Rsolvent_Fig7/(Rsolvent_Fig7+Rshell_Fig7)                           #Reduction in flux caused by shell
    
    Γdash_Raschig_Fig7[i] = α_Fig7/sqrt(1+kL_Raschig_Fig7^2 /(D_Fig5*k_Fig5)) * (k_Fig5/(D_Fig5*a_Raschig_Fig7^2))^(1/2) * (ϕ_Fig7*coth(ϕ_Fig7)-1)/(ϕ_Fig7^2/3)
    Γdash_Melapak_Fig7[i] = α_Fig7/sqrt(1+kL_Melapak_Fig7^2 /(D_Fig5*k_Fig5)) * (k_Fig5/(D_Fig5*a_Melapak_Fig7^2))^(1/2) * (ϕ_Fig7*coth(ϕ_Fig7)-1)/(ϕ_Fig7^2/3)
end

PyPlot.figure()
PyPlot.loglog(2*r_Fig7,3./r_Fig7/1000.0,"k")
PyPlot.loglog(2*r_Fig7,0.2*Γdash_Melapak_Fig7,"--g")
PyPlot.loglog(2*r_Fig7,0.1*Γdash_Melapak_Fig7,"-.g")
PyPlot.loglog(2*r_Fig7,0.05*Γdash_Melapak_Fig7,":g")
PyPlot.loglog(2*r_Fig7,0.2Γdash_Raschig_Fig7,"--b")
PyPlot.loglog(2*r_Fig7,0.1*Γdash_Raschig_Fig7,"-.b")
PyPlot.loglog(2*r_Fig7,0.05*Γdash_Raschig_Fig7,":b")
PyPlot.xlabel("MECS Diameter (m)")
PyPlot.ylabel("Γ")
PyPlot.legend(["1mm Layer","M500Y, ɛ=0.8","M500Y, ɛ=0.9","M500Y, ɛ=0.95","Raschig, ɛ=0.8","Raschig, ɛ=0.9","Raschig, ɛ=0.95"])
PyPlot.grid("on");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32426a850>)
